# %% [markdown]
# ## Install libraries

# %%
# %%capture
# !pip install wikidataintegrator
# !pip install ipyplot

# %% [markdown]
# ## Import libraries

# %%
from google.colab import files
import io
import pandas as pd
from wikidataintegrator import wdi_core
import requests
import json
import ipyplot

# %% [markdown]
# ## import csv from nederlandsesoorten.nl
# When browsing the species registry there is a download option to get the csv export of the currently. This notebook uses this export. As an example: You can download the list of [true bugs](https://www.nederlandsesoorten.nl/linnaeus_ng/app/views/search/nsr_search_extended.php?group_id=172875&author_id=&group=Wantsen+%5Bonderorde%5D&author=&presence%5B2%5D=on&presence%5B6%5D=on&presence%5B3%5D=on&presence%5B5%5D=on&presence%5B4%5D=on&sort=name-valid). Click on "Exporteer als CSV" and upload the download file through upload form below

# %%
uploaded = files.upload()
for file in uploaded.keys():
  df2 = pd.read_csv(io.BytesIO(uploaded[file]),sep="\t",skiprows=1)
# Dataset is now stored in a Pandas Dataframe
# Out:
#      <input type="file" id="files-097f0ccb-1214-4c5a-a461-010a601b58bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-097f0ccb-1214-4c5a-a461-010a601b58bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Export-20220328-081524.csv to Export-20220328-081524 (2).csv

# %% [markdown]
# ## remove the authornames from the taxon names

# %%
values = []
for species in df2["wetenschappelijke naam"].tolist():
  values.append("\""+" ".join(species.split()[:2])+"\"")

# %% [markdown]
# ## Split the list of taxon name in managable chunks for further processing

# %%
chunks = [values[x:x+30] for x in range(0, len(values), 30)]

# %% [markdown]
# ## Identify missing Wikipedia articles for specieslist uploaded

# %%
missing_list = []

for values in chunks: 
  query = """SELECT * WHERE {
              VALUES ?taxonLabel { 
                """
  query += " ".join(values) 
  query += """     }
    # ?taxon wdt:P225 ?taxonLabel .
    OPTIONAL {?commons schema:about ?taxon ;
                schema:isPartOf <https://commons.wikimedia.org/> .}
    OPTIONAL {?taxon wdt:P3151 ?inaturalist .}
    OPTIONAL {?taxon wdt:P846 ?gbif .}
    OPTIONAL {?taxon wdt:P3405 ?nlsoortid .}
    OPTIONAL {?taxon wdt:P18 ?image .}
    FILTER NOT EXISTS {?article schema:about ?taxon ;
                      schema:isPartOf <https://en.wikipedia.org/>}
    BIND (URI(CONCAT("https://andrawaag.github.io/tarsier/jupyter_link.html?name=", ?taxonLabel)) as ?tarsier)
  }
  """
  missing_list.append(wdi_core.WDFunctionsEngine.execute_sparql_query(query, as_dataframe=True))

# %% [markdown]
# ## Identify missing taxa in Wikidata

# %%
missing_wikidata_list = []
for values in chunks:
  query = """SELECT * WHERE {
              VALUES ?taxonLabel { 
                """
  query += " ".join(values) 
  query += """     }
    FILTER NOT EXISTS {?taxon wdt:P225 ?taxonLabel .}
  }
  """
  missing_wikidata_list.append(wdi_core.WDFunctionsEngine.execute_sparql_query(query, as_dataframe=True))

# %% [markdown]
# ## Find references for the species udner scrutiny

# %%
import json
references_dict = dict()
for index, row in missing_articles.iterrows():
  if not pd.isnull(row["gbif"]):
    references = json.loads(requests.get(f"https://api.gbif.org/v1/species/{row['gbif']}/references").text)
    for reference in references["results"]:
      if row['gbif'] not in references_dict.keys():
        references_dict[row['gbif']] = []
      references_dict[row['gbif']].append(reference["citation"])
    if row['gbif'] in references_dict.keys():
      missing_articles.at[index,"gbif_references"] = "# ".join(references_dict[row['gbif']])

# %% [markdown]
# ## Find reusable images through GBIF

# %%
images = dict()
for index, row in missing_articles.iterrows():
  if not pd.isnull(row["gbif"]):
    gbifid = row['gbif']

    if gbifid not in images.keys():
      images[gbifid] = dict()
      
    datasets = json.loads(requests.get("https://api.gbif.org/v1/occurrence/counts/datasets?taxonKey="+gbifid).text)
    for datasetKey in datasets.keys():
      gbifdatasets = json.loads(requests.get("https://api.gbif.org/v1/occurrence/search?taxonKey="+gbifid+"&license=CC0_1_0&mediaType=StillImage&datasetKey="+datasetKey).text)
      if gbifdatasets["count"] >0:
        for image_collection in gbifdatasets["results"]:
          for media in image_collection["media"]:
            hostingorg = json.loads(requests.get("https://api.gbif.org/v1/organization/"+image_collection["hostingOrganizationKey"]).text)['title']
            if "license" in media.keys():
              if hostingorg not in images[gbifid].keys():
                images[gbifid][hostingorg] = dict()
              images[gbifid][hostingorg][media["identifier"]] = media["license"]

for gbifid in images.keys():
  for collection in images[gbifid].keys():
    temp_images = []
    temp_labels = []
    for url in images[gbifid][collection].keys():
      temp_images.append(url)
      temp_labels.append(images[gbifid][collection][url])
    images_df = pd.DataFrame()
    images_df['images'] = temp_images
    images_df['labels'] = temp_labels
    print(str(missing_articles[missing_articles["gbif"]==gbifid]["taxonLabel"]))
    ipyplot.plot_images(images_df['images'], labels=images_df['labels'], max_images=10, )
# Out:
# 1    Ceratitis cosyra
# Name: taxonLabel, dtype: object
#     <style>
#         #ipyplot-html-viewer-toggle-Arwyby4CodddjBMzhRDvHG {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Arwyby4CodddjBMzhRDvHG {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Arwyby4CodddjBMzhRDvHG {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Arwyby4CodddjBMzhRDvHG:checked ~ #ipyplot-html-viewer-textarea-Arwyby4CodddjBMzhRDvHG {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Arwyby4CodddjBMzhRDvHG:checked + #ipyplot-html-viewer-label-Arwyby4CodddjBMzhRDvHG:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-Arwyby4CodddjBMzhRDvHG">
#         <label id="ipyplot-html-viewer-label-Arwyby4CodddjBMzhRDvHG" for="ipyplot-html-viewer-toggle-Arwyby4CodddjBMzhRDvHG">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-Arwyby4CodddjBMzhRDvHG" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-9JSoPX8ftFjTwVRUsAKRBx {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-9JSoPX8ftFjTwVRUsAKRBx {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-9JSoPX8ftFjTwVRUsAKRBx">
#     <div class="ipyplot-placeholder-div-9JSoPX8ftFjTwVRUsAKRBx">
#         <div id="ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx-4pQpKWffhCpfPYWtm4DMiC" class="ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/608bf665-2929-4207-9a99-ad7c66df9dd0</h4><img src="https://data.nhm.ac.uk/media/608bf665-2929-4207-9a99-ad7c66df9dd0"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx-4pQpKWffhCpfPYWtm4DMiC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9JSoPX8ftFjTwVRUsAKRBx">
#         <div id="ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx-FGvfykWYufPEHjAbLQNnGk" class="ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/dac51604-f65c-4a45-8c6d-d769c62a1e15</h4><img src="https://data.nhm.ac.uk/media/dac51604-f65c-4a45-8c6d-d769c62a1e15"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx-FGvfykWYufPEHjAbLQNnGk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9JSoPX8ftFjTwVRUsAKRBx">
#         <div id="ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx-feAcnk7JFYLbAtgipch67F" class="ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/22eeb01b-0e10-4886-a8f9-844cf4f95448</h4><img src="https://data.nhm.ac.uk/media/22eeb01b-0e10-4886-a8f9-844cf4f95448"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9JSoPX8ftFjTwVRUsAKRBx
jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL-Y9S8TBeGhKCTj2aFxPguyr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nY47ZzZvTUGTRYxSy8U9kL">
#         <div id="ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL-QcfZS9BpMJXtxqAdARuZkY" class="ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">© all rights reserved</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://www.artportalen.se/MediaLibrary/2019/12/4864068f-042f-4aed-9aa6-9d9751ead200_image.jpg</h4><img src="https://www.artportalen.se/MediaLibrary/2019/12/4864068f-042f-4aed-9aa6-9d9751ead200_image.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL-QcfZS9BpMJXtxqAdARuZkY">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nY47ZzZvTUGTRYxSy8U9kL">
#         <div id="ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL-SadT7jVkZ9cfAPyPJPbw9x" class="ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">© all rights reserved</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://www.artportalen.se/MediaLibrary/2019/12/54cb1b02-6de2-423d-9943-54bd19454811_image.jpg</h4><img src="https://www.artportalen.se/MediaLibrary/2019/12/54cb1b02-6de2-423d-9943-54bd19454811_image.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL-SadT7jVkZ9cfAPyPJPbw9x">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nY47ZzZvTUGTRYxSy8U9kL">
#         <div id="ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL-S5MHhQEVxN5m2PG4FCJPKJ" class="ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Michael Andersson</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://www.artportalen.se/MediaLibrary/2019/12/93430c36-848b-4481-8041-fa9b410b353c_image.jpg</h4><img src="https://www.artportalen.se/MediaLibrary/2019/12/93430c36-848b-4481-8041-fa9b410b353c_image.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL-S5MHhQEVxN5m2PG4FCJPKJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nY47ZzZvTUGTRYxSy8U9kL">
#         <div id="ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL-FJiQ3mDE3x7C6VKQ8vfW5B" class="ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">© all rights reserved</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://www.artportalen.se/MediaLibrary/2020/3/6ca2744f-b99b-4000-8ff1-228fd70d3f80_image.jpg</h4><img src="https://www.artportalen.se/MediaLibrary/2020/3/6ca2744f-b99b-4000-8ff1-228fd70d3f80_image.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL-FJiQ3mDE3x7C6VKQ8vfW5B">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nY47ZzZvTUGTRYxSy8U9kL">
#         <div id="ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL-nyTzWefKf2sNTaAMqs3EWS" class="ipyplot-content-div-nY47ZzZvTUGTRYxSy8U9kL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">© all rights reserved</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://www.artportalen.s
# 3    Horidiplosis ficifolii
# Name: taxonLabel, dtype: object
#     <style>
#         #ipyplot-html-viewer-toggle-RZyLi9VeP2K5LCM9w6m7xP {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RZyLi9VeP2K5LCM9w6m7xP {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RZyLi9VeP2K5LCM9w6m7xP {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RZyLi9VeP2K5LCM9w6m7xP:checked ~ #ipyplot-html-viewer-textarea-RZyLi9VeP2K5LCM9w6m7xP {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RZyLi9VeP2K5LCM9w6m7xP:checked + #ipyplot-html-viewer-label-RZyLi9VeP2K5LCM9w6m7xP:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-RZyLi9VeP2K5LCM9w6m7xP">
#         <label id="ipyplot-html-viewer-label-RZyLi9VeP2K5LCM9w6m7xP" for="ipyplot-html-viewer-toggle-RZyLi9VeP2K5LCM9w6m7xP">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-RZyLi9VeP2K5LCM9w6m7xP" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-QStuV3BiJ5yg7G2u2dFuMs {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-QStuV3BiJ5yg7G2u2dFuMs {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-QStuV3BiJ5yg7G2u2dFuMs">
#     <div class="ipyplot-placeholder-div-QStuV3BiJ5yg7G2u2dFuMs">
#         <div id="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-HxwLZ5WFxWXYqtwZAN9bgs" class="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/publicdomain/zero/1.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://medialib.naturalis.nl/file/id/ZMA.INS.921318/format/large</h4><img src="https://medialib.naturalis.nl/file/id/ZMA.INS.921318/format/large"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-HxwLZ5WFxWXYqtwZAN9bgs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-QStuV3BiJ5yg7G2u2dFuMs">
#         <div id="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-UK62FnMmgpFwEEPSHGWMxx" class="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/publicdomain/zero/1.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://medialib.naturalis.nl/file/id/ZMA.INS.921320/format/large</h4><img src="https://medialib.naturalis.nl/file/id/ZMA.INS.921320/format/large"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-UK62FnMmgpFwEEPSHGWMxx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-QStuV3BiJ5yg7G2u2dFuMs">
#         <div id="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-ce6aqTgLL6ZJBe9qYgYqF5" class="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/publicdomain/zero/1.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://medialib.naturalis.nl/file/id/ZMA.INS.921321/format/large</h4><img src="https://medialib.naturalis.nl/file/id/ZMA.INS.921321/format/large"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-ce6aqTgLL6ZJBe9qYgYqF5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-QStuV3BiJ5yg7G2u2dFuMs">
#         <div id="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-Ak7Zxda43bu2PLiyEvJh4d" class="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/publicdomain/zero/1.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://medialib.naturalis.nl/file/id/ZMA.INS.921319/format/large</h4><img src="https://medialib.naturalis.nl/file/id/ZMA.INS.921319/format/large"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-Ak7Zxda43bu2PLiyEvJh4d">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-QStuV3BiJ5yg7G2u2dFuMs {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-QStuV3BiJ5yg7G2u2dFuMs {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-QStuV3BiJ5yg7G2u2dFuMs">
#     <div class="ipyplot-placeholder-div-QStuV3BiJ5yg7G2u2dFuMs">
#         <div id="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-HxwLZ5WFxWXYqtwZAN9bgs" class="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/publicdomain/zero/1.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://medialib.naturalis.nl/file/id/ZMA.INS.921318/format/large</h4><img src="https://medialib.naturalis.nl/file/id/ZMA.INS.921318/format/large"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-HxwLZ5WFxWXYqtwZAN9bgs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-QStuV3BiJ5yg7G2u2dFuMs">
#         <div id="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-UK62FnMmgpFwEEPSHGWMxx" class="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/publicdomain/zero/1.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://medialib.naturalis.nl/file/id/ZMA.INS.921320/format/large</h4><img src="https://medialib.naturalis.nl/file/id/ZMA.INS.921320/format/large"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-UK62FnMmgpFwEEPSHGWMxx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-QStuV3BiJ5yg7G2u2dFuMs">
#         <div id="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-ce6aqTgLL6ZJBe9qYgYqF5" class="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/publicdomain/zero/1.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://medialib.naturalis.nl/file/id/ZMA.INS.921321/format/large</h4><img src="https://medialib.naturalis.nl/file/id/ZMA.INS.921321/format/large"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-ce6aqTgLL6ZJBe9qYgYqF5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-QStuV3BiJ5yg7G2u2dFuMs">
#         <div id="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-Ak7Zxda43bu2PLiyEvJh4d" class="ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/publicdomain/zero/1.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://medialib.naturalis.nl/file/id/ZMA.INS.921319/format/large</h4><img src="https://medialib.naturalis.nl/file/id/ZMA.INS.921319/format/large"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-QStuV3BiJ5yg7G2u2dFuMs-Ak7Zxda43bu2PLiyEvJh4d">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# 7    Dacus siliqualactis
# Name: taxonLabel, dtype: object
#     <style>
#         #ipyplot-html-viewer-toggle-Kuk2Dip7k58XzJPa7zLWRo {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Kuk2Dip7k58XzJPa7zLWRo {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Kuk2Dip7k58XzJPa7zLWRo {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Kuk2Dip7k58XzJPa7zLWRo:checked ~ #ipyplot-html-viewer-textarea-Kuk2Dip7k58XzJPa7zLWRo {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Kuk2Dip7k58XzJPa7zLWRo:checked + #ipyplot-html-viewer-label-Kuk2Dip7k58XzJPa7zLWRo:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-
">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8mfy6aRNfLVnNUFCnYn2yt">
#         <div id="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-eB3u98ksrxM8nPnsgaxuyT" class="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/publicdomain/zero/1.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://inaturalist-open-data.s3.amazonaws.com/photos/107764159/original.jpg</h4><img src="https://inaturalist-open-data.s3.amazonaws.com/photos/107764159/original.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-eB3u98ksrxM8nPnsgaxuyT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8mfy6aRNfLVnNUFCnYn2yt">
#         <div id="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-csSMNDdpiipuffKUTENWUj" class="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://inaturalist-open-data.s3.amazonaws.com/photos/31610028/original.jpeg</h4><img src="https://inaturalist-open-data.s3.amazonaws.com/photos/31610028/original.jpeg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-csSMNDdpiipuffKUTENWUj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8mfy6aRNfLVnNUFCnYn2yt">
#         <div id="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-DTP2FuzhXJRatDqGktNbFf" class="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://inaturalist-open-data.s3.amazonaws.com/photos/31417160/original.jpg</h4><img src="https://inaturalist-open-data.s3.amazonaws.com/photos/31417160/original.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-conten
#         <style>
#         #ipyplot-imgs-container-div-8mfy6aRNfLVnNUFCnYn2yt {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-8mfy6aRNfLVnNUFCnYn2yt {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-8mfy6aRNfLVnNUFCnYn2yt">
#     <div class="ipyplot-placeholder-div-8mfy6aRNfLVnNUFCnYn2yt">
#         <div id="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-AwcM2PAVfV7EHPvnVPCBXH" class="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by-nc/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://inaturalist-open-data.s3.amazonaws.com/photos/174133780/original.jpeg</h4><img src="https://inaturalist-open-data.s3.amazonaws.com/photos/174133780/original.jpeg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-AwcM2PAVfV7EHPvnVPCBXH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8mfy6aRNfLVnNUFCnYn2yt">
#         <div id="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-f3cXHB7eQJQYrHnRvAwfAt" class="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by-nc/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://inaturalist-open-data.s3.amazonaws.com/photos/174133793/original.jpeg</h4><img src="https://inaturalist-open-data.s3.amazonaws.com/photos/174133793/original.jpeg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-f3cXHB7eQJQYrHnRvAwfAt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8mfy6aRNfLVnNUFCnYn2yt">
#         <div id="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-eB3u98ksrxM8nPnsgaxuyT" class="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/publicdomain/zero/1.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://inaturalist-open-data.s3.amazonaws.com/photos/107764159/original.jpg</h4><img src="https://inaturalist-open-data.s3.amazonaws.com/photos/107764159/original.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-eB3u98ksrxM8nPnsgaxuyT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8mfy6aRNfLVnNUFCnYn2yt">
#         <div id="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-csSMNDdpiipuffKUTENWUj" class="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://inaturalist-open-data.s3.amazonaws.com/photos/31610028/original.jpeg</h4><img src="https://inaturalist-open-data.s3.amazonaws.com/photos/31610028/original.jpeg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-csSMNDdpiipuffKUTENWUj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8mfy6aRNfLVnNUFCnYn2yt">
#         <div id="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-DTP2FuzhXJRatDqGktNbFf" class="ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://inaturalist-open-data.s3.amazonaws.com/photos/31417160/original.jpg</h4><img src="https://inaturalist-open-data.s3.amazonaws.com/photos/31417160/original.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8mfy6aRNfLVnNUFCnYn2yt-DTP2FuzhXJRatDqGktNbFf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ## Download results

# %%
pd.DataFrame.from_dict(images).to_csv('gbif_images.csv')
files.download('gbif_images.csv')
result = pd.concat(missing_wikidata_list)
result.to_csv('missing_in_wikidata.csv')
files.download('missing_in_wikidata.csv')
missing_articles = pd.concat(missing_list)
missing_articles.to_csv('missing_in_wikipedia.csv')
files.download('missing_in_wikipedia.csv')
