# %% [markdown]
# ## Jupyter notebook source
# https://colab.research.google.com/drive/1KDppE8ccqMBgdz5HjP_wi7DO4C4qAOAe?usp=sharing

# %% [markdown]
# ## Install libraries

# %%
# %%capture
# !pip install wikidataintegrator
# !pip install ipyplot

# %% [markdown]
# ## Import libraries

# %%
from google.colab import files
import io
import pandas as pd
from wikidataintegrator import wdi_core
import requests
import json
import ipyplot

# %% [markdown]
# ## import csv from nederlandsesoorten.nl
# When browsing the species registry there is a download option to get the csv export of the currently. This notebook uses this export. As an example: You can download the list of [invasive insects (flies & musquitos](https://www.nederlandsesoorten.nl/linnaeus_ng/app/views/search/nsr_search_extended.php?group_id=145015&author_id=&group=Diptera++-+Vliegen+en+muggen+%5Borde%5D&author=&presence%5B2%5D=on&presence%5B6%5D=on&presence%5B3%5D=on&presence%5B5%5D=on&presence%5B4%5D=on&sort=name-valid). Click on "Exporteer als CSV" and upload the download file through upload form below

# %%
uploaded = files.upload()
for file in uploaded.keys():
  df2 = pd.read_csv(io.BytesIO(uploaded[file]),sep="\t",skiprows=1)
# Dataset is now stored in a Pandas Dataframe
# Out:
#      <input type="file" id="files-946ca062-1aa8-4852-ba14-38132f33a089" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-946ca062-1aa8-4852-ba14-38132f33a089">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Export-20220329-125627.csv to Export-20220329-125627.csv

# %% [markdown]
# ## remove the authornames from the taxon names

# %%
values = []
for species in df2["wetenschappelijke naam"].tolist():
  values.append("\""+" ".join(species.split()[:2])+"\"")

# %% [markdown]
# ## Split the list of taxon name in managable chunks for further processing

# %%
chunks = [values[x:x+30] for x in range(0, len(values), 30)]

# %% [markdown]
# ## Identify missing Wikipedia articles for specieslist uploaded

# %%
missing_list = []

for values in chunks: 
  query = """SELECT * WHERE {
              VALUES ?taxonLabel { 
                """
  query += " ".join(values) 
  query += """     }
    # ?taxon wdt:P225 ?taxonLabel .
    OPTIONAL {?commons schema:about ?taxon ;
                schema:isPartOf <https://commons.wikimedia.org/> .}
    OPTIONAL {?taxon wdt:P3151 ?inaturalist .}
    OPTIONAL {?taxon wdt:P846 ?gbif .}
    OPTIONAL {?taxon wdt:P3405 ?nlsoortid .}
    OPTIONAL {?taxon wdt:P18 ?image .}
    FILTER NOT EXISTS {?article schema:about ?taxon ;
                      schema:isPartOf <https://en.wikipedia.org/>}
    BIND (URI(CONCAT("https://andrawaag.github.io/tarsier/jupyter_link.html?name=", ?taxonLabel)) as ?tarsier)
  }
  """
  missing_list.append(wdi_core.WDFunctionsEngine.execute_sparql_query(query, as_dataframe=True))

# %% [markdown]
# ## Identify missing taxa in Wikidata

# %%
missing_wikidata_list = []
for values in chunks:
  query = """SELECT * WHERE {
              VALUES ?taxonLabel { 
                """
  query += " ".join(values) 
  query += """     }
    FILTER NOT EXISTS {?taxon wdt:P225 ?taxonLabel .}
  }
  """
  missing_wikidata_list.append(wdi_core.WDFunctionsEngine.execute_sparql_query(query, as_dataframe=True))
missing_articles = pd.concat(missing_list)

# %% [markdown]
# ## Find references for the species under scrutiny

# %%
import json
references_dict = dict()
for index, row in missing_articles.iterrows():
  if not pd.isnull(row["gbif"]):
    references = json.loads(requests.get(f"https://api.gbif.org/v1/species/{row['gbif']}/references").text)
    for reference in references["results"]:
      if row['gbif'] not in references_dict.keys():
        references_dict[row['gbif']] = []
      references_dict[row['gbif']].append(reference["citation"])
    if row['gbif'] in references_dict.keys():
      missing_articles.at[index,"gbif_references"] = "# ".join(references_dict[row['gbif']])

# %% [markdown]
# ## Find reusable images through GBIF

# %%
images = dict()
for index, row in missing_articles.iterrows():
  if not pd.isnull(row["gbif"]):
    gbifid = row['gbif']

    if gbifid not in images.keys():
      images[gbifid] = dict()
      
    datasets = json.loads(requests.get("https://api.gbif.org/v1/occurrence/counts/datasets?taxonKey="+gbifid).text)
    for datasetKey in datasets.keys():
      gbifdatasets = json.loads(requests.get("https://api.gbif.org/v1/occurrence/search?taxonKey="+gbifid+"&license=CC0_1_0&mediaType=StillImage&datasetKey="+datasetKey).text)
      if gbifdatasets["count"] >0:
        for image_collection in gbifdatasets["results"]:
          for media in image_collection["media"]:
            hostingorg = json.loads(requests.get("https://api.gbif.org/v1/organization/"+image_collection["hostingOrganizationKey"]).text)['title']
            if "license" in media.keys():
              if hostingorg not in images[gbifid].keys():
                images[gbifid][hostingorg] = dict()
              images[gbifid][hostingorg][media["identifier"]] = media["license"]
      gbifdatasets = json.loads(requests.get("https://api.gbif.org/v1/occurrence/search?taxonKey="+gbifid+"&license=CC_BY_4.0&mediaType=StillImage&datasetKey="+datasetKey).text)
      if gbifdatasets["count"] >0:
        for image_collection in gbifdatasets["results"]:
          for media in image_collection["media"]:
            hostingorg = json.loads(requests.get("https://api.gbif.org/v1/organization/"+image_collection["hostingOrganizationKey"]).text)['title']
            if "license" in media.keys():
              if hostingorg not in images[gbifid].keys():
                images[gbifid][hostingorg] = dict()
              images[gbifid][hostingorg][media["identifier"]] = media["license"]

for gbifid in images.keys():
  for collection in images[gbifid].keys():
    temp_images = []
    temp_labels = []
    for url in images[gbifid][collection].keys():
      temp_images.append(url)
      temp_labels.append(images[gbifid][collection][url])
    images_df = pd.DataFrame()
    images_df['images'] = temp_images
    images_df['labels'] = temp_labels
    print(str(missing_articles[missing_articles["gbif"]==gbifid]["taxonLabel"]))
    ipyplot.plot_images(images_df['images'], labels=images_df['labels'], max_images=10, )
# Out:
# 0    Dohrniphora cornuta
# Name: taxonLabel, dtype: object
#     <style>
#         #ipyplot-html-viewer-toggle-g5cBzwy9kau724Nn3bDNpJ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-g5cBzwy9kau724Nn3bDNpJ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-g5cBzwy9kau724Nn3bDNpJ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-g5cBzwy9kau724Nn3bDNpJ:checked ~ #ipyplot-html-viewer-textarea-g5cBzwy9kau724Nn3bDNpJ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-g5cBzwy9kau724Nn3bDNpJ:checked + #ipyplot-html-viewer-label-g5cBzwy9kau724Nn3bDNpJ:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-g5cBzwy9kau724Nn3bDNpJ">
#         <label id="ipyplot-html-viewer-label-g5cBzwy9kau724Nn3bDNpJ" for="ipyplot-html-viewer-toggle-g5cBzwy9kau724Nn3bDNpJ">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-g5cBzwy9kau724Nn3bDNpJ" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-faEM5d6YQpyhmucDSwpFY4 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-faEM5d6YQpyhmucDSwpFY4 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-faEM5d6YQpyhmucDSwpFY4 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-faEM5d6YQpyhmucDSwpFY4 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-faEM5d6YQpyhmucDSwpFY4 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-faEM5d6YQpyhmucDSwpFY4 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-faEM5d6YQpyhmucDSwpFY4 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-faEM5d6YQpyhmucDSwpFY4 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-faEM5d6YQpyhmucDSwpFY4]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-faEM5d6YQpyhmucDSwpFY4]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-faEM5d6YQpyhmucDSwpFY4]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div
after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-QzjZVwKhyUzxn4ygMQxexF">
#         <label id="ipyplot-html-viewer-label-QzjZVwKhyUzxn4ygMQxexF" for="ipyplot-html-viewer-toggle-QzjZVwKhyUzxn4ygMQxexF">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-QzjZVwKhyUzxn4ygMQxexF" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-CL6CE3PJG6DjWAX6dCyb4E {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-CL6CE3PJG6DjWAX6dCyb4E {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-CL6CE3PJG6DjWAX6dCyb4E {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-CL6CE3PJG6DjWAX6dCyb4E span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-CL6CE3PJG6DjWAX6dCyb4E span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-CL6CE3PJG6DjWAX6dCyb4E img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-CL6CE3PJG6DjWAX6dCyb4E span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-CL6CE3PJG6DjWAX6dCyb4E span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-CL6CE3PJG6DjWAX6dCyb4E]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-CL6CE3PJG6DjWAX6dCyb4E]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-CL6CE3PJG6DjWAX6dCyb4E]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-CL6CE3PJG6DjWAX6dCyb4E">
#     <div class="ipyplot-placeholder-div-CL6CE3PJG6DjWAX6dCyb4E">
#         <div id="ipyplot-content-div-CL6CE3PJG6DjWAX6dCyb4E-HRX95Jo5bKEBSjRJ2Vv3Yj" class="ipyplot-content-div-CL6CE3PJG6DjWAX6dCyb4E">
#             <h4 style="font-size: 12px; word-wrap: break-word;">© all rights reserved</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://www.artportalen.se/MediaLibrary/2019/11/7140ea0e-ef07-4f6a-ad48-0c14bed69dc5_image.jpg</h4><img src="https://www.artportalen.se/MediaLibrary/2019/11/7140ea0e-ef07-4f6a-ad48-0c14bed69dc5_image.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-CL6CE3PJG6DjWAX6dCyb4E-HRX95Jo5bKEBSjRJ2Vv3Yj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
# ...
#     <style>
#         #ipyplot-html-viewer-toggle-MwbRFSu4z24K8GtveWKZVZ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-MwbRFSu4z24K8GtveWKZVZ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-MwbRFSu4z24K8GtveWKZVZ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-MwbRFSu4z24K8GtveWKZVZ:checked ~ #ipyplot-html-viewer-textarea-MwbRFSu4z24K8GtveWKZVZ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-MwbRFSu4z24K8GtveWKZVZ:checked + #ipyplot-html-viewer-label-MwbRFSu4z24K8GtveWKZVZ:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-MwbRFSu4z24K8GtveWKZVZ">
#         <label id="ipyplot-html-viewer-label-MwbRFSu4z24K8GtveWKZVZ" for="ipyplot-html-viewer-toggle-MwbRFSu4z24K8GtveWKZVZ">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-MwbRFSu4z24K8GtveWKZVZ" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-VL3YLYAzz4B9An9PykmxrT {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-VL3YLYAzz4B9An9PykmxrT {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-VL3YLYAzz4B9An9PykmxrT">
#     <div class="ipyplot-placeholder-div-VL3YLYAzz4B9An9PykmxrT">
#         <div id="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-RSR9ihXaf7KVoxxup28cag" class="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/f08feb01-8b1d-4271-a021-62f581662fa1</h4><img src="https://data.nhm.ac.uk/media/f08feb01-8b1d-4271-a021-62f581662fa1"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-RSR9ihXaf7KVoxxup28cag">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VL3YLYAzz4B9An9PykmxrT">
#         <div id="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-FcFjcuVDB5DtcVVY6F4gNo" class="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/d4235871-c2b5-4803-954e-26eb04c99169</h4><img src="https://data.nhm.ac.uk/media/d4235871-c2b5-4803-954e-26eb04c99169"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-FcFjcuVDB5DtcVVY6F4gNo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VL3YLYAzz4B9An9PykmxrT">
#         <div id="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-Bm4q4gXPqVwSyhWNCn37i3" class="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/8117deec-9a42-44b0-9f79-3ceab3bcb884</h4><img src="https://data.nhm.ac.uk/media/8117deec-9a42-44b0-9f79-3ceab3bcb884"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-Bm4q4gXPqVwSyhWNCn37i3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VL3YLYAzz4B9An9PykmxrT">
#         <div id="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-RratKHJ8LY66NBsajNqQGt" class="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/50705e82-d829-4113-a9bf-36dbdfb7d272</h4><img src="https://data.nhm.ac.uk/media/50705e82-d829-4113-a9bf-36dbdfb7d272"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-RratKHJ8LY66NBsajNqQGt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VL3YLYAzz4B9An9PykmxrT">
#         <div id="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-ZhamYuc4mysvTcnvDmsJyU" class="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/f60158ae-3686-4e2c-9195-45f7499d6b43</h4><img src="https://data.nhm.ac.uk/media/f60158ae-3686-4e2c-9195-45f7499d6b43"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-ZhamYuc4mysvTcnvDmsJyU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         <style>
#         #ipyplot-imgs-container-div-VL3YLYAzz4B9An9PykmxrT {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-VL3YLYAzz4B9An9PykmxrT {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-VL3YLYAzz4B9An9PykmxrT">
#     <div class="ipyplot-placeholder-div-VL3YLYAzz4B9An9PykmxrT">
#         <div id="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-RSR9ihXaf7KVoxxup28cag" class="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/f08feb01-8b1d-4271-a021-62f581662fa1</h4><img src="https://data.nhm.ac.uk/media/f08feb01-8b1d-4271-a021-62f581662fa1"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-RSR9ihXaf7KVoxxup28cag">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VL3YLYAzz4B9An9PykmxrT">
#         <div id="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-FcFjcuVDB5DtcVVY6F4gNo" class="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/d4235871-c2b5-4803-954e-26eb04c99169</h4><img src="https://data.nhm.ac.uk/media/d4235871-c2b5-4803-954e-26eb04c99169"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-FcFjcuVDB5DtcVVY6F4gNo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VL3YLYAzz4B9An9PykmxrT">
#         <div id="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-Bm4q4gXPqVwSyhWNCn37i3" class="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/8117deec-9a42-44b0-9f79-3ceab3bcb884</h4><img src="https://data.nhm.ac.uk/media/8117deec-9a42-44b0-9f79-3ceab3bcb884"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-Bm4q4gXPqVwSyhWNCn37i3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VL3YLYAzz4B9An9PykmxrT">
#         <div id="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-RratKHJ8LY66NBsajNqQGt" class="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/50705e82-d829-4113-a9bf-36dbdfb7d272</h4><img src="https://data.nhm.ac.uk/media/50705e82-d829-4113-a9bf-36dbdfb7d272"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-RratKHJ8LY66NBsajNqQGt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VL3YLYAzz4B9An9PykmxrT">
#         <div id="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-ZhamYuc4mysvTcnvDmsJyU" class="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/f60158ae-3686-4e2c-9195-45f7499d6b43</h4><img src="https://data.nhm.ac.uk/media/f60158ae-3686-4e2c-9195-45f7499d6b43"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-ZhamYuc4mysvTcnvDmsJyU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VL3YLYAzz4B9An9PykmxrT">
#         <div id="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-N57XxZtXwGNd9rc2sooUWs" class="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/d7fe3a9a-bde5-425e-a5b5-b624b908db19</h4><img src="https://data.nhm.ac.uk/media/d7fe3a9a-bde5-425e-a5b5-b624b908db19"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-N57XxZtXwGNd9rc2sooUWs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VL3YLYAzz4B9An9PykmxrT">
#         <div id="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT-756UsDtHoYdHw6SpteucML" class="ipyplot-content-div-VL3YLYAzz4B9An9PykmxrT">
#             <h4 style="font-size: 12px; word-wrap: break-word;">http://creativecommons.org/licenses/by/4.0/</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://data.nhm.ac.uk/media/a70fa33d-22eb-448b-a9e5-15ebe6752736</h4><img src="https://data.nhm.ac.uk/media/a70fa33d-22eb-448b-a9e5-15ebe6752736"/>
#             <a href="#!">
#                 <span class="ipyplot-i

# %% [markdown]
# ## Download results

# %%
pd.DataFrame.from_dict(images).to_csv('gbif_images.csv')
files.download('gbif_images.csv')
result = pd.concat(missing_wikidata_list)
result.to_csv('missing_in_wikidata.csv')
files.download('missing_in_wikidata.csv')
missing_articles.to_csv('missing_in_wikipedia.csv')
files.download('missing_in_wikipedia.csv')
